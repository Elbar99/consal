# %%
from tkinter import *
import numpy as np

p = 7
n = 4

grill =  [[0 for j in range(p)] for i in range(n)]
# grill2 = np.zeros(shape=( n,p))
# G=np.zeros(shape=( n,p))       
           
# for k in range(n):
#      for i in range(len(grill2)):
#         for j in range(len(grill2[i])):
#             G[k]=grill2[i][j]
            
# print(G)            
# print(grill2)
# print(grill) 
# def peut_tomber(i,j):
#     if grill[i][j] != 0:
#         v=False
# #     if grill[i][j] != 0:
# #         grill[i-1][j] = 1
#     elif (grill[i'][j-1] or grill[i][j+1]) != 0:
#         v=False
#     else :
#         v=True
        
#     return v
def peut_tomber(i,j):
    for i in range(n):
#         for j in range(p):
#             if grill[i][j] == 0:
                if grill[i][j] == 1:
                    grill[i-1][j] = 1 and  grill[i-2][j]=0
                if (grill[i][j-1] or grill[i][j+1]) == 0:
                    grill[i][j] = 1
                if grill[-1][j] == 0:
                    grill[i][j] = 1 
            
#     print(grill)
# print(peut_tomber(3,3))        
# v= False



# def test():
#     for i in range(n):
#         for j in range(p):
#             if peut_tomber(i,j)!=0:
#                 v=False
#             else:
#                 v= True
#     return v
    
    
    
def faire_tomber_un_bloc(j):
    for i in range(n):
            peut_tomber(i,j)
        
#         peut_tomber(i,j):
#             grill[i][j]=1
#         if a==True:
#             grill[i][j]=1
faire_tomber_un_bloc(3)
print(grill)


# if grill[i][j]==1:
#     grill[i-1][j]=0
#     grill[i+1][j]=0
    

def faire_tomber_des_blocs(k):
    for j in range(k):
        faire_tomber_un_bloc(j)



#Arbres browniens)
def est_dedans(i,j):
    pass

def faire_libre(i,j):
    pass

def lancer_un_bloc():
    pass

def lancer_des_blocs(k):
    pass
# Out:
#   File "<ipython-input-12-0f51998d39e4>", line 35
#     grill[i-1][j] = 1 and  grill[i-2][j]=0
#                     ^
# SyntaxError: cannot assign to operator
